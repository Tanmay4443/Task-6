# %%
import cv2
import numpy as np
import threading
import os

# Load HAAR face classifier
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Load functions
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0

# Collect 100 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
        # Save file in specified directory with unique name
        file_name_path = './faces/user/' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face not found")

    if cv2.waitKey(1) == 13 or count == 100: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")
# Out:
# <>:17: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:17: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-1-3cad93145f32>:17: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Collecting Samples Complete

# %%
cap.release()

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join

# Get the training data we previously made
data_path = './faces/user/'
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

# Create arrays for training data and labels
Training_Data, Labels = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles):
    image_path = data_path + onlyfiles[i]
    images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    Training_Data.append(np.asarray(images, dtype=np.uint8))
    Labels.append(i)

# Create a numpy array for both training data and labels
Labels = np.asarray(Labels, dtype=np.int32)

# Initialize facial recognizer
# model = cv2.face.createLBPHFaceRecognizer()
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()
# pip install opencv-contrib-python
# model = cv2.createLBPHFaceRecognizer()
tanmay_model  = cv2.face_LBPHFaceRecognizer.create()
# Let's train our model 
tanmay_model.train(np.asarray(Training_Data), np.asarray(Labels))
print("Model trained sucessefully")
# Out:
# Model trained sucessefully

# %%
#mail function
def mail():
    os.system("python mail.py")
#Whatsapp function
def whatsapp():
    os.system("python whatsapp.py")

# %%
import cv2
import numpy as np
import os


face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []
    
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


# Open Webcam
cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()
    
    image, face = face_detector(frame)
    
    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = ishika_model.predict(face)
        # harry_model.predict(face)
        
        if results[1] < 500:
            confidence = int( 100 * (1 - (results[1])/650) )
            display_string = str(confidence) + '% Confident it is User'
            
        cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
        
        if confidence > 90:
            cv2.putText(image, "Hey TANMAY", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
           
             #For sending mail
            mail=threading.Thread(target=mail)
            mail.start()
            #For Whatsapp
            whatsapp=threading.Thread(target=whatsapp)
            whatsapp.start()
            
        
        
        else:
            cv2.putText(image, "I dont know, how r u", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )
            

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "looking for face", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass
        
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-6-a8f33768440e>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# Exception in thread Thread-526:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-527:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-528:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-529:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-530:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-531:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-533:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-532:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-535:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-534:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError:     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# 'Thread' object is not callable
# Exception in thread Exception in thread Thread-537:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-536:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)TypeError: 'Thread' object is not callable
#
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-538:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-539:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-540:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-541:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError    : 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-542:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callableException in thread
# Thread-543:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-544Thread-545:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-546:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-547:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-548:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-549:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-551:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-550:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-553:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-552:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-554:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-555:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-556:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-557:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError    self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# : 'Thread' object is not callable
# Exception in thread Thread-558Exception in thread Thread-559:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-560:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-561:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-562:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-563:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-564:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-565:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-566:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# Exception in thread Thread-567:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-569:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-568:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError:     'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-570:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-571:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-572Thread-573:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     TypeError: 'Thread' object is not callableself._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#
# Exception in thread Thread-574:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-575:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-576:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread     Thread-577:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()    self._target(*self._args, **self._kwargs)
#
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-579Thread-578:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-580:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-581:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-582:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-583:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-584:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-585:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-586:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-587:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-588:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-589:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-590:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-591:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-592:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-593:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-594:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-595:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     TypeError: 'Thread' object is not callableself._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#
# Exception in thread Exception in thread Thread-597:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-596:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-598:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-599:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-600:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-601    self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# :
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-602Exception in thread Thread-603:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()    self.run()
#
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-604:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-605:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-606Exception in thread Thread-607:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-608Exception in thread :
# Thread-609:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#     self.run()  File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-610:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-611:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-612:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-613:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-614:
# Traceback (most recent call last):
# Thread-615  File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-617:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-616:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError    self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# : 'Thread' object is not callable
# Exception in thread Exception in thread Thread-619:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-618:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-620:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-621:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-622:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-623:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError    self._target(*self._args, **self._kwargs):
# TypeError: 'Thread' object is not callable
# 'Thread' object is not callable
# Exception in thread Thread-624:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-625:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-627:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-626:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-629:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-628:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-630:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# Exception in thread Thread-631:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-632:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-633:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError    self._target(*self._args, **self._kwargs)
# : 'Thread' object is not callable
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-634:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-635:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-636:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-637:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-638:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-639:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()    self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-640:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-641:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-642:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-643:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-644:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# Exception in thread Thread-645:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-646:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-647:
# Traceback (most recent call last):
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-648:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# Exception in thread Thread-649:
# Traceback (most recent call last):
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-650:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-651:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-652:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-653:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-654:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-655:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-656:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-657:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-658:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-659:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-660:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-661:
# Traceback (most recent call last):
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-662:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-663:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-664:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-665:
# Traceback (most recent call last):
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#     self._target(*self._args, **self._kwargs)  File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-667:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-666:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-668:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# Exception in thread Thread-669:
# Traceback (most recent call last):
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-670Exception in thread Thread-671:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-672:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-673:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-674:
# Traceback (most recent call last):
# ...
# Thread-1558:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1560:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1561:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1562Exception in thread :
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-1563:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError    self._target(*self._args, **self._kwargs): 'Thread' object is not callable
# TypeError: 'Thread' object is not callable
#
# Exception in thread Thread-1564:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1565:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1566:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1567:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1568:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1569:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1570:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     Exception in thread Thread-1571:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-1573:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-1572:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError    self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# : 'Thread' object is not callable
# Exception in thread Thread-1574:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1575:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError    : 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1576:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     Exception in thread Thread-1577:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#     self._target(*self._args, **self._kwargs)  File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-1579:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-1578:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-1581:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-1580:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1582:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1583:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError    self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# : 'Thread' object is not callable
# Exception in thread Exception in thread Thread-1584:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-1585:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1586:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1587:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1588:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1589    self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# :
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-1590:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-1591:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-1593:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-1592:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-1594:
# Thread-1595:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-1597:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-1596:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#     TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-1599Thread-1598:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1600:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1601:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1602:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1603:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1604:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1605:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#         self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1606:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
# Exception in thread Thread-1607:
# Traceback (most recent call last):
#       File "C:\Users\Admin\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
